# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 10
b = 20
c = a + b
print("The sum of a and b is: ",c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# The sum of a and b is:  30
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
c = 0.3 + 0.6
print("The sum of 0.3 and 0.6 is: ",c)
# Out:
# The sum of 0.3 and 0.6 is:  0.8999999999999999

# %%
my_list = [8,10,3,5,12,7,6,20]
print(my_list[2:5])
# Out:
# [3, 5, 12]

# %%
print(my_list[-4])
# Out:
# 12

# %%
my_list=[10,12,14,15,7,8,9,11]
my_list[1:8:2]=[20,40,50,70]
print(my_list)
# Out:
# [10, 20, 14, 40, 7, 50, 9, 70]

# %%
my_list=[10,12,14,15,7,8,9,11]
my_list[1:3]=[5,5]
my_list[3:8:2]=[20,20,20]
print(my_list)
# Out:
# [10, 5, 5, 20, 7, 20, 9, 20]

# %%
my_list=[10,20,14,15,7,8,9,11]
remove_value = my_list.pop(2)
print("Removed value: ",remove_value)
print(my_list)
# Out:
# Removed value:  14
# [10, 20, 15, 7, 8, 9, 11]

# %%
my_list=[10,12,14,15,7,8,9,11]
del my_list[2]
print(my_list)
# Out:
# [10, 12, 15, 7, 8, 9, 11]

# %%
my_list=[10,12,14,15,7,8,9,11]
my_list.clear()
print(my_list)
# Out:
# []

# %%
my_list=[10,8,20,14,3]
my_list.sort()
print(my_list)
# Out:
# [3, 8, 10, 14, 20]

# %%
my_list=[10,8,20,14,3]
my_list.sort(reverse=True)
print(my_list)
# Out:
# [20, 14, 10, 8, 3]

# %%
my_list=["Apple",12,7,"apple","Banana","Badulla"]

#to sort this we need to convert all the elements to string
my_list.sort(key=str)
print(my_list)
# Out:
# [12, 7, 'Apple', 'Badulla', 'Banana', 'apple']

# %%
my_list_1=[1,3,3]
my_list_2=my_list_1.copy()
print("List 1: ",my_list_1)
print("List 2: ",my_list_2)
my_list_1[1]=20
print("After modifying List 1: ")
print("List 1: ",my_list_1)
print("List 2: ",my_list_2)
# Out:
# List 1:  [1, 3, 3]
# List 2:  [1, 3, 3]
# After modifying List 1:
# List 1:  [1, 20, 3]
# List 2:  [1, 3, 3]

# %%
my_list_1=[1,2,3]
my_list_2=[4,5,6]
my_list_3=my_list_1+my_list_2
print("Concatenated List: ",my_list_3)
# Out:
# Concatenated List:  [1, 2, 3, 4, 5, 6]

# %%
my_list_1=[1,2,3]
my_list_2=[4,5,6]
my_list_1.extend(my_list_2)
print("Extended List: ",my_list_1)
# Out:
# Extended List:  [1, 2, 3, 4, 5, 6]

# %%
my_list=[10,12,14,15,7,8,9,11]
my_list.reverse()
print(my_list)
# Out:
# [11, 9, 8, 7, 15, 14, 12, 10]
